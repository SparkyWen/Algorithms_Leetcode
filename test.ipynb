# %%
0 and 100
# Out:
# 0

# %%
100 and 100
# Out:
# 100

# %%
5 or 10
# Out:
# 5

# %%
not(0 and 100)
# Out:
# True

# %%
not(100 and 100)
# Out:
# False

# %%
2 and 3
# Out:
# 3

# %%
0 or 0
# Out:
# 0

# %%
matrix = [[1,2,3],[4,5,6],[7,8,9]]
(matrix[0])
# Out:
# [1, 2, 3]

# %%
len(matrix)
# Out:
# 4

# %%
for _ in range(3,0,-1):
    print(_)
# Out:
# 3
# 2
# 1

# %%
l, r, t, b, res = 0, len(matrix[0]) - 1, 0, len(matrix) - 1, []
print(l)
print(r)
print(t)
print(b)
# Out:
# 0
# 2
# 0
# 2
