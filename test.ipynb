# %%
0 and 100
# Out:
# 0

# %%
100 and 100
# Out:
# 100

# %%
5 or 10
# Out:
# 5

# %%
not(0 and 100)
# Out:
# True

# %%
not(100 and 100)
# Out:
# False

# %%
2 and 3
# Out:
# 3

# %%
0 or 0
# Out:
# 0
